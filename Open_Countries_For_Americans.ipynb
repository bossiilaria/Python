# %% [markdown]
# This is my second real life project after I have received my certificate on April 3 2021: YAY! The task I was given is to
# create a verifiable list of countries that are open for US travelers, update it weekly and share it with all Directors and above.
# Start from this website here [Open Countries](https://parade.com/1202599/stephanieosmanski/countries-open-to-americans-right-now/)
# Not sure these data are correct.

# %%
#Let's try to find elements with BeautifulSoup
import bs4
import requests

# %%
res = requests.get('https://parade.com/1202599/stephanieosmanski/countries-open-to-americans-right-now/')

# %%
soup = bs4.BeautifulSoup(res.content, 'lxml')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE HTML>
# <html lang="en" xml:lang="en" xmlns="https://www.w3.org/1999/xhtml">
# <head>
# <!--[if lt IE 9]><link rel="stylesheet" href="/wp-content/themes/wp-theme/css/parade/compiled/bootstrap-fixed.css?v=8" type="text/css" media=""/>
# 		<link rel="stylesheet" href="/wp-content/themes/wp-theme/css/parade/compiled/bootstrap-desktop.css?v=8" type="text/css" media=""/><![endif]-->
# <script type="text/javascript">
# /* Modernizr 2.6.2 (Custom Build) | MIT & BSD
# ...

# %%
soup.find_all('ul')
# Out:
# [<ul class="items vertical menu accordion-menu" data-accordion-menu="" data-multi-open="false" data-parent-link="true">
#  <li class="accordion subnav loginNav">
#  <a class="nav-link" href="javascript:void(0);">LOGIN</a>
#  <div class="user_login login panel menu vertical nested secondary-links">
#  <div class="login_form login-signup">
#  <div class="login_form_content">
#  <form action="" id="loginform" method="post" name="loginform">
#  </form><form>
#  <fieldset>
#  <div class="input_group">
#  <input autocomplete="username" class="field" data-parade-type="email" id="user_login--login" name="log" placeholder="Email or Username" type="text" value=""/>
#  <div class="error_message">
#  Please enter a valid email address.
#  </div>
#  </div>
#  <div class="input_group">
#  <input autocomplete="current-password" class="field" id="user_pass" name="pwd" placeholder="Password" type="password" value=""/>
#  <div class="error_message">
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()
options.headless = True
options.add_argument("--window-size=1920,1200")

driver = webdriver.Chrome(options=options, executable_path=DRIVER_PATH)
driver.get("https://parade.com/1202599/stephanieosmanski/countries-open-to-americans-right-now/")
#print(driver.page_source)
#driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-48eb1f70e376> in <module>
#       6 options.add_argument("--window-size=1920,1200")
#       7
# ----> 8 driver = webdriver.Chrome(options=options, executable_path=DRIVER_PATH)
#       9 driver.get("https://parade.com/1202599/stephanieosmanski/countries-open-to-americans-right-now/")
#      10 #print(driver.page_source)
#
# NameError: name 'DRIVER_PATH' is not defined

# %%
driver.get('https://parade.com/1202599/stephanieosmanski/countries-open-to-americans-right-now/')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3dc61f00bc34> in <module>
# ----> 1 driver.get('https://parade.com/1202599/stephanieosmanski/countries-open-to-americans-right-now/')
#
# NameError: name 'driver' is not defined
