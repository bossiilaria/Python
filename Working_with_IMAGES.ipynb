# %%
from PIL import Image

# %%
pwd
# Out:
# 'C:\\Users\\i.b.ossi\\Python'

# %%
shiva = Image.open('C:\\Users\\i.b.ossi\\Pictures\Shiva2.jpg')

# %%
type(shiva)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
shiva.size
# Out:
# (612, 470)

# %%
shiva.filename
# Out:
# 'C:\\Users\\i.b.ossi\\Pictures\\Shiva2.jpg'

# %%
shiva.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
mac.crop((100, 10, 500, 500))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ed9613055b47> in <module>
# ----> 1 mac.crop((100, 10, 500, 500))
#
# NameError: name 'mac' is not defined

# %%
x = 70
y = 70

w = 612/2
h = 470/3

# %%
shiva.crop((x, y, w, h))
# Out:
# <PIL.Image.Image image mode=RGB size=236x87 at 0x24C04DDEBB0>

# %%
shiva
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x470 at 0x24C04E676A0>

# %%
#Let's try to grab the head!
x = 200
y = 70

w = 612/1.5
h = 470/2.5

# %%
shiva.crop((x, y, w, h))
# Out:
# <PIL.Image.Image image mode=RGB size=208x118 at 0x24C04F6AD00>

# %%
#Now we can take the head and copy it at the top of the image!
head = shiva.crop((x, y, w, h))
shiva.paste(im = head, box = (0,0))
shiva.paste(im = head, box = (400,0))

# %%
shiva
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x470 at 0x24C04E676A0>

# %%
shiva.resize((700, 400))
# Out:
# <PIL.Image.Image image mode=RGB size=700x400 at 0x24C04D01640>

# %%
#Color Transparency
#Let's explore the idea of transparency as a RGBA (Red, Green, Blue, Alpha) where if alpha is 0 the pix
#is completely transparent, if alpha = 255 the pix is completely opaque
blue = Image.open('C:\\Users\\i.b.ossi\\Pictures\\Shiva2.jpg')

# %%
shiva
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x470 at 0x24C04E676A0>

# %%
blue.putalpha(0)
#I only see white the pix is completely transparent

# %%
blue.putalpha(128)

# %%
blue
#Some level of transparency
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=612x470 at 0x24C04F6AF10>

# %%
blue.putalpha(255)

# %%
blue
#totally opaque
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=612x470 at 0x24C04F6AF10>

# %%
#Let's grab another image and paste it on top of the blue pix.
orange = Image.open('C:\\Users\\i.b.ossi\\Pictures\\Shiva.PNG')

# %%
orange
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x1094 at 0x24C04F6AE80>

# %%
blue.paste(im = orange, box = (150, 200), mask = orange)

# %%
blue
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=612x470 at 0x24C04F6AF10>

# %%
#Th
