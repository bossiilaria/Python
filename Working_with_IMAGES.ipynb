# %%
from PIL import Image

# %%
pwd
# Out:
# 'C:\\Users\\i.b.ossi\\Python'

# %%
shiva = Image.open('C:\\Users\\i.b.ossi\\Pictures\Shiva2.jpg')

# %%
type(shiva)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
shiva.size
# Out:
# (612, 470)

# %%
shiva.filename
# Out:
# 'C:\\Users\\i.b.ossi\\Pictures\\Shiva2.jpg'

# %%
shiva.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
mac.crop((100, 10, 500, 500))
# Out:
# <PIL.Image.Image image mode=RGB size=400x490 at 0x2B391841A00>

# %%
x = 70
y = 70

w = 612/2
h = 470/3

# %%
shiva.crop((x, y, w, h))
# Out:
# <PIL.Image.Image image mode=RGB size=236x165 at 0x2B391A1F700>

# %%
shiva
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x470 at 0x2B3919FB5B0>

# %%
#Let's try to grab the head!
x = 200
y = 70

w = 612/1.5
h = 470/2.5

# %%
shiva.crop((x, y, w, h))
# Out:
# <PIL.Image.Image image mode=RGB size=208x118 at 0x2B391A1F520>

# %%
#Now we can take the head and copy it at the top of the image!
head = shiva.crop((x, y, w, h))
shiva.paste(im = head, box = (0,0))
shiva.paste(im = head, box = (400,0))

# %%
shiva
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x470 at 0x2B3919FB5B0>

# %%
shiva.resize((700, 400))
# Out:
# <PIL.Image.Image image mode=RGB size=700x400 at 0x2B391732280>

# %%
#Color Transparency
